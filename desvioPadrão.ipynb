# %% [markdown]
# # desvio padrão

# %%
import pandas as pd
import matplotlib.pyplot as plt

# =========================================
# 1. INFORME AQUI OS RESULTADOS DAS MÉTRICAS (%)
# =========================================
# Exemplo usando seus valores do HE
resultados_he = {
    "Contrast": [-66.36, -66.87, 64.35, -24.28, 62.22],
    "Homogeneity": [5.77, -2.94, -6.22, 1.18, -3.22],
    "Energy": [-5.83, -14.36, -2.04, -4.67, 9.70],
    "Correlation": [4.40, 5.54, 1.27, 1.15, 1.30]
}

# Ou exemplo usando CLAHE (descomente se quiser usar)
# resultados_clahe = {
#     "Contrast": [-83.97, -78.19, -30.03, -27.35, 48.59],
#     "Homogeneity": [17.95, 18.48, -3.36, 7.97, -3.0],
#     "Energy": [4.06, 2.75, -1.21, 0.65, 13.34],
#     "Correlation": [4.76, 5.50, 1.20, 0.87, 1.11]
# }

# =========================================
# 2. CRIA O DATAFRAME
# =========================================
df = pd.DataFrame(resultados_he)   # troque para resultados_clahe se quiser
print("📌 DataFrame com os valores informados:\n")
print(df)

# =========================================
# 3. CALCULA O DESVIO PADRÃO
# =========================================
std_series = df.std()
print("\n📊 Desvio padrão das métricas:\n")
print(std_series)

# =========================================
# 4. GERA O GRÁFICO DO DESVIO PADRÃO
# =========================================
plt.figure(figsize=(8,5))
std_series.plot(kind='bar')
plt.title("Desvio Padrão das Métricas GLCM")
plt.ylabel("Desvio Padrão (%)")
plt.xlabel("Métricas")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# 📌 DataFrame com os valores informados:
#
#    Contrast  Homogeneity  Energy  Correlation
# 0    -66.36         5.77   -5.83         4.40
# 1    -66.87        -2.94  -14.36         5.54
# 2     64.35        -6.22   -2.04         1.27
# 3    -24.28         1.18   -4.67         1.15
# 4     62.22        -3.22    9.70         1.30
#
# 📊 Desvio padrão das métricas:
#
# Contrast       65.737278
# Homogeneity     4.649966
# Energy          8.675987
# Correlation     2.083139
# dtype: float64
