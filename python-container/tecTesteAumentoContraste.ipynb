# %% [markdown]
# # Técnicas para Validar o Aumento de Contraste
# as técnicas apresentadas são:
# * Histograma
# * Perfil de Linha
# * GLCM

# %% [markdown]
# ## obs: importações

# %% [markdown]
# ## Histograma

# %% [markdown]
# ## Perfil de Linha

# %% [markdown]
# ## GLCM
